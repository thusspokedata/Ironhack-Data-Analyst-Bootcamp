# %% [markdown]
# ### <span style="color:#873E23">Lab | Computer Vision</span>

# %% [markdown]
# <a id='section3'></a>
# ### <span style="color:#873E23">Index</span>
#
# 1. [Task 1: Article which discusses ethical issues with computer vision applications](#section1)
# 2. [Task 2: Generate an image from a caption you provide](#section2)

# %% [markdown]
# -------

# %% [markdown]
# <a id='section1'></a>
# ### <span style="color:#873E23"> Task 1</span>
#
# <span style="color:#873E23"> I read this
# <a href="https://aeon.co/ideas/algorithms-associating-appearance-and-criminality-have-a-dark-past">article </a> about "Algorithms associating appearance and criminality".
# <br>
# There are many ethical problems connected to machine vision and facial  recognition. Once again marginalized groups of society are taken into focus which leads to a reaffirmation of the current social hierarchy. It would be interesting to see a study about the facial characteristics that show a liability for corruption.
# </span>
#
# [index](#section3)

# %% [markdown]
# -----------------

# %% [markdown]
# <a id='section2'></a>
# ### <span style="color:#873E23"> Task 2</span>
# <br>
# <span style="color:#873E23">
# The figure is well made but we have to keep in mind that it works with patriarchal patterns as the woman wears long hair although this is not true for all women.
# </span>
#
# [index](#section3)

# %% [markdown]
# ![woman%20swimming.png](attachment:woman%20swimming.png)

# %% [markdown]
# ---------------------

# %% [markdown]
# #### <span style="color:#873E23"> Will our future be like this picture? Maybe Corona just made the future arrive faster. </span>

# %% [markdown]
# ![the_private_eye.jpeg](attachment:the_private_eye.jpeg)

# %% [markdown]
# <a href="http://panelsyndicate.com/comics/tpeye">The private eye</a>
