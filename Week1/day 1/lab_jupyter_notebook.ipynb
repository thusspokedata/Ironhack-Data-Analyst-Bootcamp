# %% [markdown]
# <a id='section1'></a>
# ### Table of Contents
#
# 1. [Mr. Bean on holiday](#section2)
# 2. [Purpose of this notebook](#section3)
# 3. [Video from France](#section4)
# 3. [Mr. Bean's picture](#section5)
# 4. [Best destination for Mr. Bean](#section6)
# 5. [Things Mr. Bean likes to do in France](#section7)
# 6. [Last video](#section8)

# %% [markdown]
# <a id='section2'></a>
# # Mr Bean on holiday
#
# This is my friend Mr Bean on his holiday in France

# %% [markdown]
# ![mr%20bean%20holidays.jpeg](attachment:mr%20bean%20holidays.jpeg)

# %% [markdown]
# <a id='section3'></a>
# ### **The pourpose of this notebook:**
#
# *to share some beautiful moments of my friend.
# Have fun while you are looking at this notebook.*

# %% [markdown]
# <a id='section4'></a>
# Here is a link to a video of Mr Bean in [France](https://www.youtube.com/watch?v=mN79k7x63Bg "Mr Bean on Paris").

# %%
def your_name(name):
    print("Hi "+ name + " !!!")
    
your_name("Bean")
# Out:
# Hi Bean !!!

# %% [markdown]
# <a id='section5'></a>
# Picture of my friend:
#
# ![file-20191203-67028-qfiw3k.jpeg](attachment:file-20191203-67028-qfiw3k.jpeg)

# %%
def your_holidays_pref(country):
    print("Mr Bean has already been to", country )

country = input("What is your holiday preference: ")
your_holidays_pref(country)
# Out:
# What is your holiday preference: France
# Mr Bean has already been to France

# %% [markdown]
# <a id='section6'></a>
# The french beaches are the best destination for Mr. Bean:
#
# ![360508537.jpeg](attachment:360508537.jpeg)

# %% [markdown]
# <a id='section7'></a>
# ### <span style="color:green">Things Mr. Bean likes to do in France: </span>
# <br>
# <span style="color:green">
#     <ul>
#         <li><b>Dancing</b></li>
#         <li><b>Eating</b></li>
#         <li><b>Sleeping</b></li>
#     </ul>
# </span>

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('kSGrk5gVkmM')

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# [index](#section3)
