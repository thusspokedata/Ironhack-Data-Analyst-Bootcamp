# %% [markdown]
# ## Lab | Customer Analysis Round 3
#
# For this lab, we still keep using the marketing_customer_analysis.csv file. You can find the file in the files_for_lab folder.
# ### Get the data
# + Use the same jupyter file from the last lab, Customer Analysis Round 3
#
# ### EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:
#
# * Show DataFrame info.
# * Describe DataFrame.
# * Show a plot of the total number of responses broken down by response kind.
# * Show a plot of the response rate number of responses by the sales channel.
# * Show a plot of the response rate by the total claim amount. Show a plot of the distribution of the total claim amount, broken down by response kind. Try a boxplot and distribution plot, for each response kind. For the distribution plot, try to plot both kinds of responses in one chart (you can try with seaborn's histplot, using the hue parameter).
# * Show a plot of the response rate by income. Create similar plots like in the task before, but for Income
# * NEW: Create a scatterplot between total claim amount and income. Play around with the parameters of the scatterplot (markersize? alpha?) and try to identify more features within the data just visually. You can also try different seaborn plots.

# %%
import numpy as np
import pandas as pd
import datetime
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Show DataFrame info.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employment_status              9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %%
df.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %% [markdown]
# ### Show a plot of the total number of responses broken down by response kind.

# %%
sns.countplot(x='response', data=df)
plt.title('Responses broken down by response kind')
sns.set_style("dark")
plt.show()

# %%
sns.countplot(x='sales_channel', data=df)
plt.title('Sales Channel Histogram')
sns.set_style("dark")
plt.show()

# %% [markdown]
# ### Show a plot of the number of responses by the sales channel.

# %%
sns.countplot(x='response', data=df, hue='sales_channel', color='purple')
plt.title('Number of responses by the sales channel')
sns.set_style("dark")
plt.show()

# %% [markdown]
# ### Show a plot of the distribution of the total claim amount, broken down by response kind.

# %%
sns.histplot(x='total_claim_amount', data=df, hue='response', element="poly")
plt.title('Distribution of the total claim amount, broken down by response kind')
sns.set_style("dark")
plt.show()

# %%
### Try a boxplot and distribution plot, for each response kind.

# %%
sns.boxplot(y='response',x="total_claim_amount", data=df)
plt.show()

# %%
sns.boxplot(x='total_claim_amount', y= 'response', data=df)
plt.show()

# %%
sns.displot(df, x="response", y="total_claim_amount", bins=20)
plt.show()

# %%
sns.displot(df, x="response", y="sales_channel", bins=20)
plt.show()

# %% [markdown]
# ### For the distribution plot, try to plot both kinds of responses in one chart (you can try with seaborn's histplot, using the hue parameter).

# %%
sns.histplot(x='income', data=df, hue='response')
plt.show()

# %% [markdown]
# ### Create similar plots like in the task before, but for Income

# %%
sns.boxplot(y = 'response', x ='income', data=df)
plt.show()

# %% [markdown]
# ### NEW: Create a scatterplot between total claim amount and income. Play around with the parameters of the scatterplot (markersize? alpha?) and try to identify more features within the data just visually. You can also try different seaborn plots.

# %%
plt.scatter(x=df['total_claim_amount'], y=df['income'], color='#7FFFD4', alpha=0.05,)

plt.show()

# %%
plt.scatter(x=df['total_claim_amount'], y=df['income'], color='#00FFFF', alpha=0.1,)

plt.show()

# %%
sns.relplot(x=df['total_claim_amount'], y=df['income'], color='#FF7F50', alpha=0.1)

plt.show()

# %%
plt.figure(figsize=(15,8))
sns.violinplot(data=df, x=df['response'], y=df['income'])
# Out:
# <AxesSubplot:xlabel='response', ylabel='income'>
